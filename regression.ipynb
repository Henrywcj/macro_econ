# %%
import pandas as pd
import statsmodels.formula.api as sm
#from statsmodels.iolib.summary2 import summary_col
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('comb_df.csv', index_col=0)

# %%
df
# Out:
#               M1SL     M2SL     TB3MS     TB6MS      GDPC1  USRECQ    3M  \
# DATE
# 1854-09-30     NaN      NaN       NaN       NaN        NaN     1.0   NaN
# 1854-12-31     NaN      NaN       NaN       NaN        NaN     0.0   NaN
# 1855-03-31     NaN      NaN       NaN       NaN        NaN     0.0   NaN
# 1855-06-30     NaN      NaN       NaN       NaN        NaN     0.0   NaN
# 1855-09-30     NaN      NaN       NaN       NaN        NaN     0.0   NaN
# ...            ...      ...       ...       ...        ...     ...   ...
# 2019-12-31  3947.4  15251.2  1.576667  1.570000  19253.959     1.0  1.57
# 2020-03-31  4003.1  15446.9  1.110000  1.093333  19010.848     1.0  0.30
# 2020-06-30  5035.3  17868.6  0.143333  0.166667  17302.511     1.0  0.16
# 2020-09-30  5391.2  18404.0  0.113333  0.126667        NaN     NaN  0.11
# 2020-12-31  5502.5  18648.3  0.100000  0.110000        NaN     NaN  0.10
#
#               1Y    2Y    3Y  ...      NYSE_Low    NYSE_Close  NYSE_Adj Close  \
# DATE                          ...
# 1854-09-30   NaN   NaN   NaN  ...           NaN           NaN             NaN
# 1854-12-31   NaN   NaN   NaN  ...           NaN           NaN             NaN
# 1855-03-31   NaN   NaN   NaN  ...           NaN           NaN             NaN
# 1855-06-30   NaN   NaN   NaN  ...           NaN           NaN             NaN
# 1855-09-30   NaN   NaN   NaN  ...           NaN           NaN             NaN
# ...          ...   ...   ...  ...           ...           ...             ...
# 2019-12-31  1.55  1.61  1.63  ...  28169.529297  28256.029297    28256.029297
# 2020-03-31  0.33  0.45  0.50  ...  20735.019531  24345.720703    24345.720703
# 2020-06-30  0.18  0.19  0.22  ...  25523.509766  26428.320313    26428.320313
# 2020-09-30  0.13  0.13  0.16  ...  26143.769531  26501.599609    26501.599609
# 2020-12-31  0.13  0.15  0.19  ...  29231.199219  29263.480469    29263.480469
#
#              NYSE_Volume    SP500_Open    SP500_High     SP500_Low  \
# DATE
# 1854-09-30           NaN           NaN           NaN           NaN
# 1854-12-31           NaN           NaN           NaN           NaN
# 1855-03-31           NaN           NaN           NaN           NaN
# 1855-06-30           NaN           NaN           NaN           NaN
# 1855-09-30           NaN           NaN           NaN           NaN
# ...                  ...           ...           ...           ...
# 2019-12-31  6.170770e+09  28638.970703  29373.619141  28169.529297
# 2020-03-31  9.805160e+09  21227.380859  24764.769531  20735.019531
# 2020-06-30  8.210370e+09  25879.380859  27071.330078  25523.509766
# 2020-09-30  8.439930e+09  27940.630859  28957.900391  26143.769531
# 2020-12-31  3.087394e+08  29437.570313  29469.890625  29231.199219
#
#              SP500_Close  SP500_Adj Close  SP500_Volume
# DATE
# 1854-09-30           NaN              NaN           NaN
# 1854-12-31           NaN              NaN           NaN
# 1855-03-31           NaN              NaN           NaN
# 1855-06-30           NaN              NaN           NaN
# 1855-09-30           NaN              NaN           NaN
# ...                  ...              ...           ...
# 2019-12-31  28256.029297     28256.029297  6.170770e+09
# 2020-03-31  24345.720703     24345.720703  9.805160e+09
# 2020-06-30  26428.320313     26428.320313  8.210370e+09
# 2020-09-30  26501.599609     26501.599609  8.439930e+09
# 2020-12-31  29263.480469     29263.480469  3.087394e+08
#
# [666 rows x 33 columns]

# %%
df.rename(columns={'3M': 'r3M', '1Y': 'r1Y', '2Y': 'r2Y', '3Y': 'r3Y', '5Y': 'r5Y', 
           '7Y': 'r7Y', '10Y': 'r10Y', '20Y': 'r20Y', '30Y': 'r30Y', 
                   'DJIA_Adj Close': 'DJIA_Adj_Close', 'NYSE_Adj Close': 'NYSE_Adj_Close',
                  'SP500_Adj Close': 'SP500_Adj_Close'}, inplace=True)

# %%
df.columns
# Out:
# Index(['M1SL', 'M2SL', 'TB3MS', 'TB6MS', 'GDPC1', 'USRECQ', 'r3M', 'r1Y',
#        'r2Y', 'r3Y', 'r5Y', 'r7Y', 'r10Y', 'r20Y', 'r30Y', 'DJIA_Open',
#        'DJIA_High', 'DJIA_Low', 'DJIA_Close', 'DJIA_Adj_Close', 'DJIA_Volume',
#        'NYSE_Open', 'NYSE_High', 'NYSE_Low', 'NYSE_Close', 'NYSE_Adj_Close',
#        'NYSE_Volume', 'SP500_Open', 'SP500_High', 'SP500_Low', 'SP500_Close',
#        'SP500_Adj_Close', 'SP500_Volume'],
#       dtype='object')

# %%
df['NYSE_return'] = df.NYSE_Adj_Close.pct_change()
df['SP500_return'] = df.SP500_Adj_Close.pct_change()
df['DJIA_return'] = df.DJIA_Adj_Close.pct_change()
df['Spread'] = df['r10Y'] - df['r3M']

# %%
df = df[['Spread', 'USRECQ', 'M1SL', 'M2SL', 'TB3MS', 'TB6MS', 'GDPC1', 'r3M', 'r1Y',
       'r2Y', 'r3Y', 'r5Y', 'r7Y', 'r10Y', 'r20Y', 'r30Y', 'NYSE_return', 'SP500_return', 'DJIA_return']]

# %% [markdown]
# #  One Predictor

# %%
results = []
for i in range(1, 9):
    names = []
    prsquareds = []
    tvalues = []
    df_temp = df.copy()
    df_temp['y'] = df_temp.USRECQ.shift(-i)
    for var in df_temp.columns:
        if var in ['y']:
            continue
        formula = 'y ~ ' + var
        names.append(formula)
        logitfit = sm.logit(formula = formula, data = df_temp).fit(disp=0)
        tvalues.append(logitfit.tvalues[var])
        prsquareds.append(logitfit.prsquared)
    df_temp = pd.DataFrame((names, prsquareds, tvalues)).T
    df_temp.columns = ['model', 'prsquared_'+str(i) , 'tstat_'+str(i)]
    df_temp.set_index('model', inplace=True)
    results.append(df_temp)
summary = pd.concat(results, axis=1)

# %%
summary
# Out:
#                  prsquared_1   tstat_1  prsquared_2   tstat_2 prsquared_3  \
# model
# y ~ Spread         0.0755966  -2.63645     0.186171   -3.6458    0.300881
# y ~ USRECQ          0.470131   15.7681     0.202897    11.985   0.0622884
# y ~ M1SL          0.00273582 -0.707604   0.00291261 -0.728876  0.00287675
# y ~ M2SL          0.00072499 -0.370737  0.000895837 -0.411283  0.00105331
# y ~ TB3MS          0.0313455   3.05368    0.0373126   3.31843   0.0366488
# y ~ TB6MS          0.0788667   3.81394    0.0905544   4.04393   0.0909143
# y ~ GDPC1         0.00648782  -1.24608   0.00599616  -1.19824  0.00589971
# y ~ r3M           0.00623598  0.806525   0.00726861  0.851392  0.00322211
# y ~ r1Y            0.0400083   2.99738     0.051433   3.34778   0.0616427
# y ~ r2Y            0.0382497   2.22455    0.0422292   2.33014   0.0471118
# y ~ r3Y            0.0241783   2.34494    0.0297293   2.57393   0.0346491
# y ~ r5Y            0.0182562   2.04394     0.021497   2.19863    0.024177
# y ~ r7Y            0.0263556   2.11915    0.0223045   1.93212   0.0199902
# y ~ r10Y           0.0118867   1.65299     0.012993   1.71443   0.0141189
# y ~ r20Y          0.00567414    -1.054   0.00407407 -0.896973  0.00400823
# y ~ r30Y            0.021811   -1.5228    0.0171925  -1.35892   0.0163494
# y ~ NYSE_return     0.160166  -3.59523    0.0360411  -1.84866   0.0200357
# y ~ SP500_return    0.160166  -3.59523    0.0360411  -1.84866   0.0200357
# y ~ DJIA_return     0.160166  -3.59523    0.0360411  -1.84866   0.0200357
#
#                    tstat_3 prsquared_4   tstat_4  prsquared_5   tstat_5  \
# model
# y ~ Spread         -3.9849    0.360081  -4.04732     0.387737  -4.05075
# y ~ USRECQ         7.02068  0.00872075   2.65775  0.000168413 -0.365577
# y ~ M1SL         -0.724076  0.00277153 -0.710685   0.00258622 -0.686821
# y ~ M2SL         -0.445161  0.00121736 -0.477713   0.00134964 -0.502217
# y ~ TB3MS          3.28741   0.0300131   2.98301    0.0200135   2.44314
# y ~ TB6MS          4.04603   0.0786016    3.7954    0.0576987   3.29897
# y ~ GDPC1         -1.18802  0.00611759  -1.20847   0.00639532  -1.23414
# y ~ r3M           0.552276  0.00730998  0.831997    0.0130752   1.11092
# y ~ r1Y            3.60949    0.063155    3.6193    0.0468657    3.1489
# y ~ r2Y            2.45139   0.0503604   2.52627    0.0439089   2.36349
# y ~ r3Y            2.74938   0.0357372   2.76668    0.0260664   2.36992
# y ~ r5Y            2.31026   0.0248661    2.3221     0.017043    1.9237
# y ~ r7Y            1.80981   0.0175173   1.67538    0.0127962   1.41554
# y ~ r10Y           1.77203   0.0138682   1.74077   0.00877163   1.38174
# y ~ r20Y         -0.889225  0.00409282  -0.89754   0.00355794  -0.83788
# y ~ r30Y          -1.32552   0.0158534  -1.28116    0.0130021  -1.14218
# y ~ NYSE_return    -1.3794  0.00978614   -0.9602    0.0015092 -0.372806
# y ~ SP500_return   -1.3794  0.00978614   -0.9602    0.0015092 -0.372806
# y ~ DJIA_return    -1.3794  0.00978614   -0.9602    0.0015092 -0.372806
#
#                   prsquared_6   tstat_6  prsquared_7   tstat_7  prsquared_8  \
# model
# y ~ Spread           0.355869  -4.07262      0.28463  -3.99252     0.240555
# y ~ USRECQ         0.00459742  -1.88518   0.00922013  -2.64443   0.00476244
# y ~ M1SL           0.00129856 -0.485744  0.000413859 -0.273547  1.59136e-05
# y ~ M2SL          0.000631978 -0.341771   0.00016035 -0.171151  1.30874e-07
# y ~ TB3MS           0.0124908   1.93025   0.00550454   1.27722   0.00115192
# y ~ TB6MS           0.0417313   2.83132    0.0288825    2.3477    0.0182045
# y ~ GDPC1          0.00677668  -1.26866   0.00721675  -1.30727   0.00576234
# y ~ r3M             0.0158718   1.22143    0.0128012     1.096   0.00557077
# y ~ r1Y             0.0381398   2.85198    0.0257646   2.35479    0.0112851
# y ~ r2Y             0.0473445   2.44585    0.0388747   2.22253    0.0222433
# y ~ r3Y             0.0221475   2.18499    0.0147666   1.78468   0.00538702
# y ~ r5Y             0.0144132   1.76772   0.00908846   1.40148   0.00263085
# y ~ r7Y             0.0126448   1.40563    0.0084736   1.14977   0.00223722
# y ~ r10Y           0.00674236   1.20918    0.0035393  0.872829  0.000427986
# y ~ r20Y           0.00233372 -0.675407   0.00164042 -0.562497   0.00124416
# y ~ r30Y            0.0158433  -1.22823     0.019246  -1.31584    0.0231054
# y ~ NYSE_return   0.000379483  0.184037  0.000332754 -0.173793    0.0101945
# y ~ SP500_return  0.000379483  0.184037  0.000332754 -0.173793    0.0101945
# y ~ DJIA_return   0.000379483  0.184037  0.000332754 -0.173793    0.0101945
#
#                      tstat_8
# model
# y ~ Spread          -3.86068
# y ~ USRECQ          -1.91662
# y ~ M1SL          -0.0534677
# y ~ M2SL          0.00485629
# y ~ TB3MS           0.579883
# y ~ TB6MS            1.85113
# y ~ GDPC1           -1.16213
# y ~ r3M             0.722108
# y ~ r1Y              1.56067
# y ~ r2Y              1.69051
# y ~ r3Y              1.07497
# y ~ r5Y             0.749963
# y ~ r7Y             0.589099
# y ~ r10Y            0.300989
# y ~ r20Y             -0.4859
# y ~ r30Y            -1.39828
# y ~ NYSE_return       0.9296
# y ~ SP500_return      0.9296
# y ~ DJIA_return       0.9296

# %% [markdown]
# # Two Predictors

# %%
results = []
for i in range(1, 9):
    names = []
    prsquareds = []
    tvalues = []
    df_temp = df.copy()
    df_temp['y'] = df_temp.USRECQ.shift(-i)
    for var in df_temp.columns:
        if var in ['y', 'Spread']:
            continue
        formula = 'y ~ Spread + ' + var
        names.append(formula)
        #print(formula)
        logitfit = sm.logit(formula = formula, data = df_temp).fit(maxiter=100, disp=0)
        tvalues.append(logitfit.tvalues[var])
        prsquareds.append(logitfit.prsquared)
    df_temp = pd.DataFrame((names, prsquareds, tvalues)).T
    df_temp.columns = ['model', 'prsquared_'+str(i) , 'tstat_'+str(i)]
    df_temp.set_index('model', inplace=True)
    results.append(df_temp)
summary = pd.concat(results, axis=1)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "

# %%
summary
# Out:
#                           prsquared_1    tstat_1 prsquared_2   tstat_2  \
# model
# y ~ Spread + USRECQ          0.617817     4.4063    0.412696   4.01635
# y ~ Spread + M1SL           0.0757917   0.142064    0.187911   0.41742
# y ~ Spread + M2SL           0.0810766   0.758712    0.197004   1.04174
# y ~ Spread + TB3MS          0.0766671   0.333531    0.186774 -0.241384
# y ~ Spread + TB6MS          0.0766459   0.330262    0.186834 -0.252859
# y ~ Spread + GDPC1          0.0830547   0.867642    0.204188   1.30342
# y ~ Spread + r3M            0.0755981  0.0122542    0.188703 -0.489643
# y ~ Spread + r1Y            0.0756031 -0.0259059    0.189245 -0.537865
# y ~ Spread + r2Y             0.075717  -0.110779    0.190445 -0.632219
# y ~ Spread + r3Y            0.0757488  -0.124505    0.190591 -0.643017
# y ~ Spread + r5Y            0.0756818 -0.0932597    0.189882 -0.590734
# y ~ Spread + r7Y            0.0756446 -0.0700535    0.189657 -0.572943
# y ~ Spread + r10Y           0.0755981  0.0122542    0.188703 -0.489643
# y ~ Spread + r20Y           0.0863271   -1.01047    0.196183 -0.955766
# y ~ Spread + r30Y            0.106527   -1.68077    0.217862  -1.65938
# y ~ Spread + NYSE_return      0.27161    -3.8727    0.248008  -2.59945
# y ~ Spread + SP500_return     0.27161    -3.8727    0.248008  -2.59945
# y ~ Spread + DJIA_return      0.27161    -3.8727    0.248008  -2.59945
#
#                           prsquared_3   tstat_3 prsquared_4  tstat_4  \
# model
# y ~ Spread + USRECQ          0.355509    2.3098    0.380236  1.43685
# y ~ Spread + M1SL            0.309986  0.933481    0.381002  1.40404
# y ~ Spread + M2SL            0.325865   1.52565     0.39977   1.8898
# y ~ Spread + TB3MS           0.318232  -1.20215    0.379051  -1.2453
# y ~ Spread + TB6MS           0.318824  -1.21918     0.37888 -1.23728
# y ~ Spread + GDPC1           0.343724   1.89973    0.415299  2.11788
# y ~ Spread + r3M             0.324112  -1.36955    0.385586  -1.4186
# y ~ Spread + r1Y             0.326636  -1.43101    0.384942 -1.39746
# y ~ Spread + r2Y              0.32899  -1.49266    0.387013 -1.45343
# y ~ Spread + r3Y             0.329278  -1.50179    0.388022 -1.47969
# y ~ Spread + r5Y             0.327503  -1.46012    0.386925 -1.45469
# y ~ Spread + r7Y             0.326757  -1.44129    0.386869 -1.45332
# y ~ Spread + r10Y            0.324112  -1.36955    0.385586  -1.4186
# y ~ Spread + r20Y            0.323205  -1.35908    0.391261 -1.57282
# y ~ Spread + r30Y            0.349426  -1.95519    0.410373 -1.98248
# y ~ Spread + NYSE_return     0.356982  -2.33299    0.397904 -1.98926
# y ~ Spread + SP500_return    0.356982  -2.33299    0.397904 -1.98926
# y ~ Spread + DJIA_return     0.356982  -2.33299    0.397904 -1.98926
#
#                           prsquared_5   tstat_5 prsquared_6      tstat_6  \
# model
# y ~ Spread + USRECQ          0.388365  0.246897    0.378252 -6.17581e-05
# y ~ Spread + M1SL            0.430477   1.96772    0.415458      2.31232
# y ~ Spread + M2SL            0.450506   2.31393    0.432426      2.54526
# y ~ Spread + TB3MS           0.407547  -1.26387    0.374286     -1.21924
# y ~ Spread + TB6MS           0.405372  -1.19454    0.371833     -1.13801
# y ~ Spread + GDPC1           0.461602   2.38831    0.438368      2.50468
# y ~ Spread + r3M             0.410147  -1.33077    0.372187     -1.14873
# y ~ Spread + r1Y             0.405131  -1.18107    0.366462    -0.936996
# y ~ Spread + r2Y             0.405821  -1.20642    0.366282    -0.932225
# y ~ Spread + r3Y             0.406826  -1.23831    0.366725    -0.951648
# y ~ Spread + r5Y             0.407939  -1.27174    0.368259     -1.01283
# y ~ Spread + r7Y             0.409397  -1.31288    0.369966      -1.0756
# y ~ Spread + r10Y            0.410147  -1.33077    0.372187     -1.14873
# y ~ Spread + r20Y            0.419322  -1.57422    0.384066     -1.48759
# y ~ Spread + r30Y            0.432607   -1.8849    0.404996     -1.95197
# y ~ Spread + NYSE_return     0.398876  -1.31742    0.350068    -0.471915
# y ~ Spread + SP500_return    0.398876  -1.31742    0.350068    -0.471915
# y ~ Spread + DJIA_return     0.398876  -1.31742    0.350068    -0.471915
#
#                           prsquared_7     tstat_7 prsquared_8      tstat_8
# model
# y ~ Spread + USRECQ           0.30985 -0.00117686      0.2675 -0.000289551
# y ~ Spread + M1SL            0.344559     2.35429    0.300131      2.35704
# y ~ Spread + M2SL            0.356801     2.51752    0.307653      2.44586
# y ~ Spread + TB3MS           0.304414    -1.26192    0.271702     -1.55243
# y ~ Spread + TB6MS           0.301572    -1.17204    0.267115     -1.44169
# y ~ Spread + GDPC1           0.363731      2.4655    0.312863      2.37028
# y ~ Spread + r3M             0.297922    -1.04664    0.263603     -1.34981
# y ~ Spread + r1Y             0.292234   -0.803086    0.256124     -1.12463
# y ~ Spread + r2Y             0.291731   -0.779196    0.255222     -1.09736
# y ~ Spread + r3Y             0.292078   -0.797821    0.255618     -1.11254
# y ~ Spread + r5Y             0.293645   -0.873804    0.257946     -1.18975
# y ~ Spread + r7Y             0.295175   -0.940804    0.260692     -1.27236
# y ~ Spread + r10Y            0.297922    -1.04664    0.263603     -1.34981
# y ~ Spread + r20Y            0.302818    -1.21584    0.256077      -1.1296
# y ~ Spread + r30Y            0.327136    -1.82192    0.276495     -1.68827
# y ~ Spread + NYSE_return     0.285293   -0.893653    0.235334     0.492632
# y ~ Spread + SP500_return    0.285293   -0.893653    0.235334     0.492632
# y ~ Spread + DJIA_return     0.285293   -0.893653    0.235334     0.492632

# %% [markdown]
# # Playing with Spread

# %%
df['Spread_10Y2Y'] = df['r10Y'] - df['r2Y']
df.rename(columns={'Spread':'Spread_10Y3M'}, inplace=True)
# Out:
# <ipython-input-12-bd762b3a8a96>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Spread_10Y2Y'] = df['r10Y'] - df['r2Y']
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
results = []
for i in range(1, 9):
    names = []
    prsquareds = []
    tvalues = []
    df_temp = df.copy()
    df_temp['y'] = df_temp.USRECQ.shift(-i)
    for var in ['Spread_10Y3M', 'Spread_10Y2Y']:
        if var in ['y']:
            continue
        formula = 'y ~ ' + var
        names.append(formula)
        logitfit = sm.logit(formula = formula, data = df_temp).fit(disp=0)
        tvalues.append(logitfit.tvalues[var])
        prsquareds.append(logitfit.prsquared)
    df_temp = pd.DataFrame((names, prsquareds, tvalues)).T
    df_temp.columns = ['model', 'prsquared_'+str(i) , 'tstat_'+str(i)]
    df_temp.set_index('model', inplace=True)
    results.append(df_temp)
summary = pd.concat(results, axis=1)

# %%
summary
# Out:
#                  prsquared_1  tstat_1 prsquared_2  tstat_2 prsquared_3  \
# model
# y ~ Spread_10Y3M   0.0755966 -2.63645    0.186171  -3.6458    0.300881
# y ~ Spread_10Y2Y   0.0885552 -3.14335     0.13455 -3.68948    0.195558
#
#                   tstat_3 prsquared_4  tstat_4 prsquared_5  tstat_5  \
# model
# y ~ Spread_10Y3M  -3.9849    0.360081 -4.04732    0.387737 -4.05075
# y ~ Spread_10Y2Y -4.15604    0.247848 -4.41068    0.246696 -4.40949
#
#                  prsquared_6  tstat_6 prsquared_7  tstat_7 prsquared_8  \
# model
# y ~ Spread_10Y3M    0.355869 -4.07262     0.28463 -3.99252    0.240555
# y ~ Spread_10Y2Y    0.275207 -4.51068    0.249391    -4.43    0.194949
#
#                   tstat_8
# model
# y ~ Spread_10Y3M -3.86068
# y ~ Spread_10Y2Y -4.16628

# %%
results = []
for i in range(1, 9):
    names = []
    prsquareds1 = []
    prsquareds2 = []
    tvalues1 = []
    tvalues2 = []
    df_temp = df.copy()
    df_temp['y'] = df_temp.USRECQ.shift(-i)
    for var in df_temp.columns:
        if var in ['y', 'Spread_10Y3M', 'Spread_10Y2Y']:
            continue
        formula1 = 'y ~ Spread_10Y3M + ' + var
        formula2 = 'y ~ Spread_10Y2Y + ' + var
        names.append('y ~ Spread + '+ var) 
        logitfit1 = sm.logit(formula = formula1, data = df_temp).fit(maxiter=100, disp=0)
        logitfit2 = sm.logit(formula = formula2, data = df_temp).fit(maxiter=100, disp=0)
        tvalues1.append(logitfit1.tvalues[var])
        tvalues2.append(logitfit2.tvalues[var])
        prsquareds1.append(logitfit1.prsquared)
        prsquareds2.append(logitfit2.prsquared)
    df_temp = pd.DataFrame((names, prsquareds1, prsquareds2, tvalues1, tvalues2)).T
    df_temp.columns = ['model', 'prsquared_10Y3M_lag'+str(i) , 'prsquared_10Y2Y_lag'+str(i) , 'tstat_10Y3M_lag'+str(i), 'tstat_10Y2Y_lag'+str(i)]
    df_temp.set_index('model', inplace=True)
    results.append(df_temp)
summary = pd.concat(results, axis=1)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:567: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warn("Maximum Likelihood optimization failed to converge. "

# %%
summary
# Out:
#                           prsquared_10Y3M_lag1 prsquared_10Y2Y_lag1  \
# model
# y ~ Spread + USRECQ                   0.617817             0.539894
# y ~ Spread + M1SL                    0.0757917            0.0929337
# y ~ Spread + M2SL                    0.0810766             0.103597
# y ~ Spread + TB3MS                   0.0766671            0.0925624
# y ~ Spread + TB6MS                   0.0766459            0.0918484
# y ~ Spread + GDPC1                   0.0830547              0.10637
# y ~ Spread + r3M                     0.0755981            0.0393762
# y ~ Spread + r1Y                     0.0756031            0.0887528
# y ~ Spread + r2Y                      0.075717            0.0885554
# y ~ Spread + r3Y                     0.0757488            0.0885675
# y ~ Spread + r5Y                     0.0756818            0.0885818
# y ~ Spread + r7Y                     0.0756446             0.088584
# y ~ Spread + r10Y                    0.0755981            0.0885554
# y ~ Spread + r20Y                    0.0863271             0.113048
# y ~ Spread + r30Y                     0.106527             0.110754
# y ~ Spread + NYSE_return               0.27161             0.195591
# y ~ Spread + SP500_return              0.27161             0.195591
# y ~ Spread + DJIA_return               0.27161             0.195591
#
#                           tstat_10Y3M_lag1 tstat_10Y2Y_lag1  \
# model
# y ~ Spread + USRECQ                 4.4063          5.41204
# y ~ Spread + M1SL                 0.142064         0.769974
# y ~ Spread + M2SL                 0.758712          1.42921
# y ~ Spread + TB3MS                0.333531         0.718978
# y ~ Spread + TB6MS                0.330262         0.652163
# y ~ Spread + GDPC1                0.867642          1.51255
# y ~ Spread + r3M                 0.0122542        -0.421126
# y ~ Spread + r1Y                -0.0259059         0.159538
# y ~ Spread + r2Y                 -0.110779       0.00410718
# y ~ Spread + r3Y                 -0.124505       -0.0397438
# y ~ Spread + r5Y                -0.0932597       -0.0584599
# y ~ Spread + r7Y                -0.0700535       -0.0608409
# y ~ Spread + r10Y                0.0122542       0.00410718
# y ~ Spread + r20Y                 -1.01047         -1.67981
# y ~ Spread + r30Y                 -1.68077         -2.08524
# y ~ Spread + NYSE_return           -3.8727         -3.67342
# y ~ Spread + SP500_return          -3.8727         -3.67342
# y ~ Spread + DJIA_return           -3.8727         -3.67342
#
#                           prsquared_10Y3M_lag2 prsquared_10Y2Y_lag2  \
# model
# y ~ Spread + USRECQ                   0.412696             0.265918
# y ~ Spread + M1SL                     0.187911             0.142707
# y ~ Spread + M2SL                     0.197004             0.156326
# y ~ Spread + TB3MS                    0.186774             0.136112
# y ~ Spread + TB6MS                    0.186834              0.13522
# y ~ Spread + GDPC1                    0.204188             0.163687
# y ~ Spread + r3M                      0.188703             0.109033
# y ~ Spread + r1Y                      0.189245               0.1357
# y ~ Spread + r2Y                      0.190445             0.137138
# y ~ Spread + r3Y                      0.190591             0.137283
# y ~ Spread + r5Y                      0.189882             0.137503
# y ~ Spread + r7Y                      0.189657             0.137603
# y ~ Spread + r10Y                     0.188703             0.137138
# y ~ Spread + r20Y                     0.196183             0.161242
# y ~ Spread + r30Y                     0.217862             0.196512
# y ~ Spread + NYSE_return              0.248008             0.140011
# y ~ Spread + SP500_return             0.248008             0.140011
# y ~ Spread + DJIA_return              0.248008             0.140011
#
#                           tstat_10Y3M_lag2 tstat_10Y2Y_lag2  \
# model
# y ~ Spread + USRECQ                4.01635          4.04756
# y ~ Spread + M1SL                  0.41742          1.05542
# y ~ Spread + M2SL                  1.04174          1.71581
# y ~ Spread + TB3MS               -0.241384         0.448589
# y ~ Spread + TB6MS               -0.252859         0.293858
# y ~ Spread + GDPC1                 1.30342          1.91766
# y ~ Spread + r3M                 -0.489643         -1.10425
# y ~ Spread + r1Y                 -0.537865        -0.383015
# y ~ Spread + r2Y                 -0.632219        -0.572483
# y ~ Spread + r3Y                 -0.643017        -0.587919
# y ~ Spread + r5Y                 -0.590734        -0.610867
# y ~ Spread + r7Y                 -0.572943         -0.62108
# y ~ Spread + r10Y                -0.489643        -0.572483
# y ~ Spread + r20Y                -0.955766         -1.73928
# y ~ Spread + r30Y                 -1.65938         -2.19356
# y ~ Spread + NYSE_return          -2.59945         -2.24989
# y ~ Spread + SP500_return         -2.59945         -2.24989
# y ~ Spread + DJIA_return          -2.59945         -2.24989
#
#                           prsquared_10Y3M_lag3 prsquared_10Y2Y_lag3  \
# model
# y ~ Spread + USRECQ                   0.355509             0.216439
# y ~ Spread + M1SL                     0.309986             0.211461
# y ~ Spread + M2SL                     0.325865             0.228864
# y ~ Spread + TB3MS                    0.318232             0.195891
# y ~ Spread + TB6MS                    0.318824              0.19684
# y ~ Spread + GDPC1                    0.343724             0.240741
# y ~ Spread + r3M                      0.324112             0.199765
# y ~ Spread + r1Y                      0.326636              0.20385
# y ~ Spread + r2Y                       0.32899              0.20758
# y ~ Spread + r3Y                      0.329278             0.207344
# y ~ Spread + r5Y                      0.327503             0.207992
# y ~ Spread + r7Y                      0.326757             0.208462
# y ~ Spread + r10Y                     0.324112              0.20758
# y ~ Spread + r20Y                     0.323205             0.233065
# y ~ Spread + r30Y                     0.349426             0.318279
# y ~ Spread + NYSE_return              0.356982             0.210296
# y ~ Spread + SP500_return             0.356982             0.210296
# y ~ Spread + DJIA_return              0.356982             0.210296
#
#                           tstat_10Y3M_lag3 tstat_10Y2Y_lag3  \
# model
# y ~ Spread + USRECQ                 2.3098          1.70823
# y ~ Spread + M1SL                 0.933481          1.47561
# y ~ Spread + M2SL                  1.52565          2.10388
# y ~ Spread + TB3MS                -1.20215        -0.206212
# y ~ Spread + TB6MS                -1.21918        -0.403606
# y ~ Spread + GDPC1                 1.89973          2.34762
# y ~ Spread + r3M                  -1.36955         -1.91514
# y ~ Spread + r1Y                  -1.43101         -1.01514
# y ~ Spread + r2Y                  -1.49266         -1.21332
# y ~ Spread + r3Y                  -1.50179         -1.20086
# y ~ Spread + r5Y                  -1.46012         -1.23238
# y ~ Spread + r7Y                  -1.44129         -1.25487
# y ~ Spread + r10Y                 -1.36955         -1.21332
# y ~ Spread + r20Y                 -1.35908         -2.01827
# y ~ Spread + r30Y                 -1.95519          -2.4702
# y ~ Spread + NYSE_return          -2.33299         -1.98415
# y ~ Spread + SP500_return         -2.33299         -1.98415
# y ~ Spread + DJIA_return          -2.33299         -1.98415
#
#                           prsquared_10Y3M_lag4 prsquared_10Y2Y_lag4  \
# model
# y ~ Spread + USRECQ                   0.380236             0.247849
# y ~ Spread + M1SL                     0.381002             0.275511
# y ~ Spread + M2SL                      0.39977             0.296477
# y ~ Spread + TB3MS                    0.379051             0.255513
# y ~ Spread + TB6MS                     0.37888                0.259
# y ~ Spread + GDPC1                    0.415299             0.311039
# y ~ Spread + r3M                      0.385586             0.281424
# y ~ Spread + r1Y                      0.384942             0.270507
# y ~ Spread + r2Y                      0.387013             0.274907
# y ~ Spread + r3Y                      0.388022             0.274795
# y ~ Spread + r5Y                      0.386925             0.274624
# y ~ Spread + r7Y                      0.386869             0.275409
# y ~ Spread + r10Y                     0.385586             0.274907
# y ~ Spread + r20Y                     0.391261             0.303448
# y ~ Spread + r30Y                     0.410373             0.414445
# y ~ Spread + NYSE_return              0.397904             0.270108
# y ~ Spread + SP500_return             0.397904             0.270108
# y ~ Spread + DJIA_return              0.397904             0.270108
#
#                           tstat_10Y3M_lag4 tstat_10Y2Y_lag4  \
# model
# y ~ Spread + USRECQ                1.43685       -0.0152044
# y ~ Spread + M1SL                  1.40404          1.93665
# y ~ Spread + M2SL                   1.8898           2.5027
# y ~ Spread + TB3MS                 -1.2453        -0.974262
# y ~ Spread + TB6MS                -1.23728         -1.16681
# y ~ Spread + GDPC1                 2.11788          2.71038
# y ~ Spread + r3M                   -1.4186         -2.11143
# y ~ Spread + r1Y                  -1.39746         -1.63635
# y ~ Spread + r2Y                  -1.45343         -1.77171
# y ~ Spread + r3Y                  -1.47969         -1.76677
# y ~ Spread + r5Y                  -1.45469         -1.76179
# y ~ Spread + r7Y                  -1.45332         -1.78569
# y ~ Spread + r10Y                  -1.4186         -1.77171
# y ~ Spread + r20Y                 -1.57282         -2.37449
# y ~ Spread + r30Y                 -1.98248         -2.72552
# y ~ Spread + NYSE_return          -1.98926         -1.68854
# y ~ Spread + SP500_return         -1.98926         -1.68854
# y ~ Spread + DJIA_return          -1.98926         -1.68854
#
#                           prsquared_10Y3M_lag5 prsquared_10Y2Y_lag5  \
# model
# y ~ Spread + USRECQ                   0.388365             0.254165
# y ~ Spread + M1SL                     0.430477             0.278779
# y ~ Spread + M2SL                     0.450506             0.298548
# y ~ Spread + TB3MS                    0.407547             0.262903
# y ~ Spread + TB6MS                    0.405372             0.265782
# y ~ Spread + GDPC1                    0.461602             0.312003
# y ~ Spread + r3M                      0.410147              0.40556
# y ~ Spread + r1Y                      0.405131              0.28094
# y ~ Spread + r2Y                      0.405821             0.283979
# y ~ Spread + r3Y                      0.406826             0.283176
# y ~ Spread + r5Y                      0.407939             0.283667
# y ~ Spread + r7Y                      0.409397             0.284631
# y ~ Spread + r10Y                     0.410147             0.283979
# y ~ Spread + r20Y                     0.419322             0.298994
# y ~ Spread + r30Y                     0.432607             0.434647
# y ~ Spread + NYSE_return              0.398876             0.358945
# y ~ Spread + SP500_return             0.398876             0.358945
# y ~ Spread + DJIA_return              0.398876             0.358945
#
#                           tstat_10Y3M_lag5 tstat_10Y2Y_lag5  \
# model
# y ~ Spread + USRECQ               0.246897        -0.907941
# y ~ Spread + M1SL                  1.96772          2.07659
# y ~ Spread + M2SL                  2.31393          2.57005
# y ~ Spread + TB3MS                -1.26387         -1.39707
# y ~ Spread + TB6MS                -1.19454         -1.50647
# y ~ Spread + GDPC1                 2.38831          2.74271
# y ~ Spread + r3M                  -1.33077         -2.36756
# y ~ Spread + r1Y                  -1.18107         -1.97604
# y ~ Spread + r2Y                  -1.20642         -2.04454
# y ~ Spread + r3Y                  -1.23831         -2.02225
# y ~ Spread + r5Y                  -1.27174         -2.03454
# y ~ Spread + r7Y                  -1.31288         -2.05854
# y ~ Spread + r10Y                 -1.33077         -2.04454
# y ~ Spread + r20Y                 -1.57422         -2.30129
# y ~ Spread + r30Y                  -1.8849         -2.66621
# y ~ Spread + NYSE_return          -1.31742         -1.11245
# y ~ Spread + SP500_return         -1.31742         -1.11245
# y ~ Spread + DJIA_return          -1.31742         -1.11245
#
#                           prsquared_10Y3M_lag6 prsquared_10Y2Y_lag6  \
# model
# y ~ Spread + USRECQ                   0.378252             0.283859
# y ~ Spread + M1SL                     0.415458             0.321568
# y ~ Spread + M2SL                     0.432426             0.342185
# y ~ Spread + TB3MS                    0.374286             0.316868
# y ~ Spread + TB6MS                    0.371833             0.318153
# y ~ Spread + GDPC1                    0.438368             0.353892
# y ~ Spread + r3M                      0.372187             0.446836
# y ~ Spread + r1Y                      0.366462             0.322682
# y ~ Spread + r2Y                      0.366282             0.323441
# y ~ Spread + r3Y                      0.366725              0.32201
# y ~ Spread + r5Y                      0.368259             0.321904
# y ~ Spread + r7Y                      0.369966             0.323295
# y ~ Spread + r10Y                     0.372187             0.323441
# y ~ Spread + r20Y                     0.384066             0.331868
# y ~ Spread + r30Y                     0.404996             0.405925
# y ~ Spread + NYSE_return              0.350068              0.37963
# y ~ Spread + SP500_return             0.350068              0.37963
# y ~ Spread + DJIA_return              0.350068              0.37963
#
#                           tstat_10Y3M_lag6 tstat_10Y2Y_lag6  \
# model
# y ~ Spread + USRECQ           -6.17581e-05        -0.970072
# y ~ Spread + M1SL                  2.31232          2.45651
# y ~ Spread + M2SL                  2.54526          2.85812
# y ~ Spread + TB3MS                -1.21924         -2.15071
# y ~ Spread + TB6MS                -1.13801         -2.17203
# y ~ Spread + GDPC1                 2.50468          2.94589
# y ~ Spread + r3M                  -1.14873         -2.45108
# y ~ Spread + r1Y                 -0.936996         -2.27083
# y ~ Spread + r2Y                 -0.932225         -2.27634
# y ~ Spread + r3Y                 -0.951648          -2.2444
# y ~ Spread + r5Y                  -1.01283         -2.24224
# y ~ Spread + r7Y                   -1.0756         -2.27109
# y ~ Spread + r10Y                 -1.14873         -2.27634
# y ~ Spread + r20Y                 -1.48759         -2.36485
# y ~ Spread + r30Y                 -1.95197         -2.71764
# y ~ Spread + NYSE_return         -0.471915        -0.339755
# y ~ Spread + SP500_return        -0.471915        -0.339755
# y ~ Spread + DJIA_return         -0.471915        -0.339755
#
#                           prsquared_10Y3M_lag7 prsquared_10Y2Y_lag7  \
# model
# y ~ Spread + USRECQ                    0.30985             0.257385
# y ~ Spread + M1SL                     0.344559             0.299164
# y ~ Spread + M2SL                     0.356801             0.316322
# y ~ Spread + TB3MS                    0.304414             0.311741
# y ~ Spread + TB6MS                    0.301572             0.309514
# y ~ Spread + GDPC1                    0.363731             0.322706
# y ~ Spread + r3M                      0.297922              0.41353
# y ~ Spread + r1Y                      0.292234             0.304467
# y ~ Spread + r2Y                      0.291731               0.3028
# y ~ Spread + r3Y                      0.292078             0.302061
# y ~ Spread + r5Y                      0.293645             0.301781
# y ~ Spread + r7Y                      0.295175             0.302321
# y ~ Spread + r10Y                     0.297922               0.3028
# y ~ Spread + r20Y                     0.302818             0.300753
# y ~ Spread + r30Y                     0.327136             0.360146
# y ~ Spread + NYSE_return              0.285293             0.346907
# y ~ Spread + SP500_return             0.285293             0.346907
# y ~ Spread + DJIA_return              0.285293             0.346907
#
#                           tstat_10Y3M_lag7 tstat_10Y2Y_lag7  \
# model
# y ~ Spread + USRECQ            -0.00117686        -0.935451
# y ~ Spread + M1SL                  2.35429          2.54613
# y ~ Spread + M2SL                  2.51752             2.87
# y ~ Spread + TB3MS                -1.26192         -2.55879
# y ~ Spread + TB6MS                -1.17204         -2.51108
# y ~ Spread + GDPC1                  2.4655          2.86445
# y ~ Spread + r3M                  -1.04664         -2.47706
# y ~ Spread + r1Y                 -0.803086         -2.42347
# y ~ Spread + r2Y                 -0.779196         -2.37889
# y ~ Spread + r3Y                 -0.797821         -2.36107
# y ~ Spread + r5Y                 -0.873804         -2.35531
# y ~ Spread + r7Y                 -0.940804          -2.3663
# y ~ Spread + r10Y                 -1.04664         -2.37889
# y ~ Spread + r20Y                 -1.21584         -2.26302
# y ~ Spread + r30Y                 -1.82192         -2.71082
# y ~ Spread + NYSE_return         -0.893653        -0.857267
# y ~ Spread + SP500_return        -0.893653        -0.857267
# y ~ Spread + DJIA_return         -0.893653        -0.857267
#
#                           prsquared_10Y3M_lag8 prsquared_10Y2Y_lag8  \
# model
# y ~ Spread + USRECQ                     0.2675             0.201322
# y ~ Spread + M1SL                     0.300131             0.238244
# y ~ Spread + M2SL                     0.307653             0.249923
# y ~ Spread + TB3MS                    0.271702             0.264381
# y ~ Spread + TB6MS                    0.267115             0.260014
# y ~ Spread + GDPC1                    0.312863             0.250721
# y ~ Spread + r3M                      0.263603             0.368673
# y ~ Spread + r1Y                      0.256124              0.25731
# y ~ Spread + r2Y                      0.255222             0.256167
# y ~ Spread + r3Y                      0.255618             0.255444
# y ~ Spread + r5Y                      0.257946             0.255696
# y ~ Spread + r7Y                      0.260692             0.256706
# y ~ Spread + r10Y                     0.263603             0.256167
# y ~ Spread + r20Y                     0.256077             0.238764
# y ~ Spread + r30Y                     0.276495             0.255184
# y ~ Spread + NYSE_return              0.235334             0.275997
# y ~ Spread + SP500_return             0.235334             0.275997
# y ~ Spread + DJIA_return              0.235334             0.275997
#
#                           tstat_10Y3M_lag8 tstat_10Y2Y_lag8
# model
# y ~ Spread + USRECQ           -0.000289551        -0.842364
# y ~ Spread + M1SL                  2.35704          2.40348
# y ~ Spread + M2SL                  2.44586          2.65009
# y ~ Spread + TB3MS                -1.55243         -2.68786
# y ~ Spread + TB6MS                -1.44169         -2.60882
# y ~ Spread + GDPC1                 2.37028          2.55223
# y ~ Spread + r3M                  -1.34981         -2.62636
# y ~ Spread + r1Y                  -1.12463         -2.56731
# y ~ Spread + r2Y                  -1.09736         -2.52993
# y ~ Spread + r3Y                  -1.11254         -2.51155
# y ~ Spread + r5Y                  -1.18975         -2.51501
# y ~ Spread + r7Y                  -1.27236           -2.534
# y ~ Spread + r10Y                 -1.34981         -2.52993
# y ~ Spread + r20Y                  -1.1296         -2.11664
# y ~ Spread + r30Y                 -1.68827         -2.51588
# y ~ Spread + NYSE_return          0.492632         0.508604
# y ~ Spread + SP500_return         0.492632         0.508604
# y ~ Spread + DJIA_return          0.492632         0.508604
